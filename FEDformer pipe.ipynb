# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Giordano_Controls/Time-Series-Library/
# Out:
# /content/drive/.shortcut-targets-by-id/1jMiJZ40Vwym_u4NEJoLcqoWgJT0x3Y0t/Giordano_Controls/Time-Series-Library

# %% [markdown]
# # Prepare the requirements

# %%
#!git clone https://github.com/thuml/Time-Series-Library.git

# %%
#DA RUNNARE SOLO LA PRIMA VOLTA DOPO AVER FATTO IL CLONE PRIMA DEI REQUIREMENTS
#!sed -i '/torch==1\.7\.1/d' requirements.txt
#!sed -i '/torchvision==/d' requirements.txt  # if there's a similar torchvision constraint

# %%
# %pip install -r requirements.txt
# !pip install --upgrade pandas
#!pip install CityLearn
# Out:
# ...
#   Using cached pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
# Using cached pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# pymc 5.20.1 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# %env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
 #!python -m pip install "dask[dataframe]" --upgrade

# %%
ls
# Out:
#  checkpoints/                        layers/                     result_anomaly_detection.txt
#  CONTRIBUTING.md                     LICENSE                     run.py
# 'Copia di prova_TSnet.ipynb'         models/                     scripts/
# 'Copia di TimesNet_tutorial.ipynb'   pic/                        test_results/
#  data_provider/                     'prova mio TimesNet.ipynb'   tutorial/
#  exp/                                prova_TSnet.ipynb           utils/
#  final_freq_res_19.csv               README.md
#  final_freq_res_9.csv                requirements.txt

# %% [markdown]
# # TimesNet

# %%
anomaly_detection_FEDformer_48_48_48_512__FEDformer_tirocinio_sbagliato_ftMS_sl48_ll48_pl48_dm512_nh8_el2_dl1_df2048_expand2_dc4_fc1_ebtimeF_dtTrue_test_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7f73cfa37810> in <cell line: 0>()
# ----> 1 anomaly_detection_FEDformer_48_48_48_512__FEDformer_tirocinio_sbagliato_ftMS_sl48_ll48_pl48_dm512_nh8_el2_dl1_df2048_expand2_dc4_fc1_ebtimeF_dtTrue_test_0
#
# NameError: name 'anomaly_detection_FEDformer_48_48_48_512__FEDformer_tirocinio_sbagliato_ftMS_sl48_ll48_pl48_dm512_nh8_el2_dl1_df2048_expand2_dc4_fc1_ebtimeF_dtTrue_test_0' is not defined

# %%
# --anomaly_ratio 0.00132 \

# !python run.py \
  --task_name anomaly_detection \
  --is_training 0 \
  --model_id FEDformer_48_48_48_512_ \
  --model FEDformer \
  --data tirocinio_sbagliato \
  --root_path ./ \
  --data_path final_freq_res_9.csv \
  --features MS \
  --target code \
  --anomaly_ratio 0.00132 \
  --seq_len 48  \
  --label_len 48 \
  --pred_len 48 \
  --batch_size 512 \
  --enc_in 15 \
  --dec_in 15 \
  --num_workers 0 \
  --c_out 1
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        0
#   Model ID:           FEDformer_48_48_48_512_Model:              FEDformer
#
# Data Loader
#   Data:               tirocinio_sbagliato Root Path:          ./
#   Data Path:          final_freq_res_9.csvFeatures:           MS
#   Target:             code                Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      0.00132
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             15                  Dec In:             15
# ...

# %% [markdown]
# ## TEST

# %% [markdown]
# finestra 3h: 569-284
# finestra 5h: 918-459
# finestra 1D: 3988-1994
# per cambiare le finestre:
# - cambiare iperparametri run
# - cambiare finestre in data_provider/data_loader-> create_windowed_dataset
# - cambiare win_size in exp/anomaly_detection -> test (quasi in fondo)

# %%
# --anomaly_ratio 0.00132 \

# !python run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --model_id TimesNet_TRIAL1_1D_7D_epochs3 \
  --model TimesNet \
  --data tirocinio \
  --root_path ./ \
  --data_path final_freq_res_9.csv \
  --features MS \
  --target code \
  --seq_len 1994  \
  --label_len 3988 \
  --pred_len 1994 \
  --anomaly_ratio 0.5 \
  --batch_size 12 \
  --enc_in 15 \
  --dec_in 15 \
  --train_epoch 1 \
  --num_workers 0 \
  --train_epoch 3 \
  --c_out 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        1
#   Model ID:           TimesNet_TRIAL1_1D_7D_epochs3Model:              TimesNet
#
# Data Loader
#   Data:               tirocinio           Root Path:          ./
#   Data Path:          final_freq_res_9.csvFeatures:           MS
#   Target:             code                Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      0.5
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             15                  Dec In:             15
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               2048
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# ## DA NON CANCELLARE

# %%
# --anomaly_ratio 0.00132 \

# !python run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --model_id FEDformer_TRIAL2_code_True \
  --model FEDformer \
  --data tirocinio \
  --root_path ./ \
  --data_path final_freq_res_9.csv \
  --features MS \
  --target code \
  --seq_len 459  \
  --label_len 918 \
  --pred_len 459 \
  --anomaly_ratio 0.5 \
  --batch_size 4 \
  --enc_in 16 \
  --dec_in 16 \
  --train_epoch 1 \
  --num_workers 0 \
  --c_out 1
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        1
#   Model ID:           FEDformer_TRIAL2_code_TrueModel:              FEDformer
#
# Data Loader
#   Data:               tirocinio           Root Path:          ./
#   Data Path:          final_freq_res_9.csvFeatures:           MS
#   Target:             code                Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      0.25
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             16                  Dec In:             16
# ...

# %% [markdown]
# # non runnare

# %%
#non toccare perchè ouput
# --anomaly_ratio 0.00132 \

# !python run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --model_id FEDformer_TRIAL_code_True \
  --model FEDformer \
  --data tirocinio \
  --root_path ./ \
  --data_path final_freq_res_9.csv \
  --features MS \
  --target code \
  --seq_len 459  \
  --label_len 918 \
  --pred_len 459 \
  --batch_size 64 \
  --enc_in 16 \
  --dec_in 16 \
  --num_workers 0 \
  --c_out 1
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        1
#   Model ID:           FEDformer_TRIAL_code_TrueModel:              FEDformer
#
# Data Loader
#   Data:               tirocinio           Root Path:          ./
#   Data Path:          final_freq_res_9.csvFeatures:           MS
#   Target:             code                Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      0.25
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             16                  Dec In:             16
# ...

# %% [markdown]
# # controllo dataset (serve per debug)

# %%
import pandas as pd
df = pd.read_csv('resampling_non_corretto_completo.csv', low_memory=False)

# %%
print(df.columns)
print(df.info())
# Out:
# Index(['en_parziale_risc_cald', 'en_tot_risc_cald',
#        'en_parziale_sanitari_cald', 'en_tot_sanitari_cald', 'glob', 'day_x',
#        'on_off_x', 'active_x', 'daily', 'code_maint', 'flow', 'active_y',
#        'temeprature', 'boost', 'on_off_y', 'day_y', 'flame', 'pressure',
#        'service_mode', 'standby_daily', 'code_combined'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   en_parziale_risc_cald      1048575 non-null  float64
#  1   en_tot_risc_cald           1048575 non-null  float64
#  2   en_parziale_sanitari_cald  1048575 non-null  float64
#  3   en_tot_sanitari_cald       1048575 non-null  float64
#  4   glob                       1048575 non-null  float64
#  5   day_x                      1048575 non-null  float64
# ...

# %%
df['code_combined'].sum()
# Out:
# 5

# %%
# prompt: salvami il nuovo df in un csv

df.to_csv('resampling_non_corretto1.csv', index=False)

# %%
df = df.tail(10000)

# %%
print("Columns:", df.columns.tolist())
print("Shape:", df.shape)
# Out:
# Columns: ['en_parziale_risc_cald', 'en_tot_risc_cald', 'en_parziale_sanitari_cald', 'en_tot_sanitari_cald', 'glob', 'day_x', 'on_off_x', 'active_x', 'daily', 'code_maint', 'flow', 'active_y', 'temeprature', 'boost', 'on_off_y', 'day_y', 'flame', 'pressure', 'service_mode', 'standby_daily', 'code_combined']
# Shape: (20000, 21)

# %% [markdown]
# # FEDformer

# %%
# !python run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --model_id TimesNet_resampling \
  --model FEDformer \
  --data resampling_non_corretto_completo \
  --root_path ./ \
  --data_path resampling_non_corretto_completo.csv \
  --features MS \
  --target code_combined \
  --anomaly_ratio 0.000123 \
  --seq_len 48 \
  --label_len 48 \
  --pred_len 48 \
  --enc_in 20 \
  --dec_in 20 \
  --num_workers 0 \
  --c_out 1
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        1
#   Model ID:           TimesNet_resampling Model:              FEDformer
#
# Data Loader
#   Data:               resampling_non_corretto_completoRoot Path:          ./
#   Data Path:          resampling_non_corretto_completo.csvFeatures:           MS
#   Target:             code_combined       Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      0.000123
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
# ...

# %% [markdown]
# # Autoformer

# %%
# !python run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --model_id TimesNet_resampling \
  --model Autoformer \
  --data resampling_non_corretto_completo \
  --root_path ./ \
  --data_path resampling_non_corretto_completo.csv \
  --features MS \
  --target code_combined \
  --anomaly_ratio 0.000123 \
  --seq_len 48 \
  --label_len 48 \
  --pred_len 48 \
  --enc_in 20 \
  --dec_in 20 \
  --num_workers 0 \
  --c_out 1
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        1
#   Model ID:           TimesNet_resampling Model:              Autoformer
#
# Data Loader
#   Data:               resampling_non_corretto_completoRoot Path:          ./
#   Data Path:          resampling_non_corretto_completo.csvFeatures:           MS
#   Target:             code_combined       Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      0.000123
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
# ...

# %% [markdown]
# #TimeXer

# %%
# !python run.py \
  --task_name short_term_forecast \
  --is_training 1 \
  --model_id TimesNet_resampling \
  --model TimeXer \
  --data resampling_non_corretto_completo \
  --root_path ./ \
  --data_path resampling_non_corretto_completo.csv \
  --features MS \
  --target code_combined \
  --anomaly_ratio 0.000123 \
  --seq_len 48 \
  --label_len 48 \
  --pred_len 48 \
  --enc_in 20 \
  --dec_in 20 \
  --num_workers 0 \
  --c_out 1
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          short_term_forecast Is Training:        1
#   Model ID:           TimesNet_resampling Model:              TimeXer
#
# Data Loader
#   Data:               resampling_non_corretto_completoRoot Path:          ./
#   Data Path:          resampling_non_corretto_completo.csvFeatures:           MS
#   Target:             code_combined       Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            48                  Label Len:          48
#   Pred Len:           48                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# ...
